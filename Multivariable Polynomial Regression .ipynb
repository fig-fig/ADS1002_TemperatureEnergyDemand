# %% [markdown]
# Multivariate Polynomial Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DF = pd.read_csv('tempDemand.csv')

# %%
DF = DF.dropna()
DF.dtypes
# Out:
# dateTime        object
# Temperature    float64
# TOTALDEMAND    float64
# dtype: object

# %%
X = DF.iloc[:, 1:2].values
Y = DF.iloc[:, 2].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression() # create model object
lin_reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regr = PolynomialFeatures(degree = 4) # our polynomial model is of order
X_poly = poly_regr.fit_transform(X) # transforms the features to the polynomial form
lin_reg_2 = LinearRegression() # creates a linear regression object
lin_reg_2.fit(X_poly, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'darkseagreen', s=10) 
plt.plot(X, lin_reg_2.predict(poly_regr.fit_transform(X)), color = 'teal')
plt.title('Demand vs Temperature')
plt.xlabel('Temperature') 
plt.ylabel('Demand')
# Out:
# Text(0, 0.5, 'Demand')

# %%
X = DF['Temperature'].values.reshape(-1,1)
y = DF['TOTALDEMAND'].values.reshape(-1,1)

# %%
# Linear Regression 
regressor = LinearRegression()
regressor.fit(X,y)
y_pred=regressor.predict(X)


rmse = np.sqrt(mean_squared_error(y,y_pred))
r2 = r2_score(y,y_pred)
print('RMSE score is '+ str(rmse))
print('R Squared score is '+str(r2))
# Out:
# RMSE score is 878.8224754564357
# R Squared score is 0.026199141681438998

# %%
#Polynomial Regression 
poly = PolynomialFeatures(degree = 4)

X_poly = poly.fit_transform(X)
regressor = LinearRegression()
regressor.fit(X_poly,y)
y_poly_pred=regressor.predict(X_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('RMSE score is '+ str(rmse))
print('R Squared is '+str(r2))
# Out:
# RMSE score is 804.8587071462244
# R Squared is 0.18321616146167807
