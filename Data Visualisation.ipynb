# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns


data = pd.read_csv('tempDemand.csv')

data["dateTime"] = pd.to_datetime(data["dateTime"])

data = data.dropna()

# %%
# data = data[['TOTALDEMAND', 'Temperature']]
# grouped = data.groupby([data.index.month, data.index.day]).mean()
# grouped

# %%
# Let's find the warmeset days in the data set 

data.sort_values('Temperature')

sns.lineplot(data.index, data["Temperature"])
# Out:
# c:\Users\kelsa\anaconda3\envs\maps\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Temperature'>

# %%
# rolling_mean = data['TOTALDEMAND'].rolling('1D').mean()
# centered_rolling_mean = data['TOTALDEMAND'].rolling(16, center=True).mean()
# data['TOTALDEMAND'].plot.line(label='Data', figsize=(20,8))
# rolling_mean.plot.line(label='Rolling Mean')
# centered_rolling_mean.plot.line(label="Centered Rolling Mean")
# plt.legend()

# %%
# start = "2014-01-01 00:00:00"
# end = "2014-01-31 23:30:00"

    
fig, ax = plt.subplots(figsize=(25, 7))
ax2 = ax.twinx()

ax.plot(data['dateTime'], data["TOTALDEMAND"], color='darkseagreen', label="Demand")
ax2.plot(data['dateTime'], data["Temperature"], color='Teal', label="Temperature")
plt.gca().get_lines()[0].set_alpha(0.5)
plt.legend()
plt.title("Demand Vs Temperature over time")
plt.xlabel('date')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
tempDemand = pd.read_csv("tempDemandData.csv")

tempDemand.head()

from sklearn import preprocessing
import pandas as pd
scaler = preprocessing.MinMaxScaler()
names = tempDemand[['TOTALDEMAND','Temperature']].columns
d = scaler.fit_transform(tempDemand[['TOTALDEMAND','Temperature']])
scaled_df = pd.DataFrame(d, columns=names)
scaled_df.head()

scaled_df.corr()
# Out:
#              TOTALDEMAND  Temperature
# TOTALDEMAND     1.000000     0.161861
# Temperature     0.161861     1.000000

# %%
tempDemand.head(50)

tempDemand.plot.scatter('Temperature', 'TOTALDEMAND', color='Teal', figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='TOTALDEMAND'>
